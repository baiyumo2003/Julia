# %%
print(1==2)
# Out:
# false

# %%
using Plots
x = 0:0.01:2pi; y = sin; # These are the plotting data
plot(0:0.0001:pi, cos)
plot(0:0.01:2pi,sin)

# %%
versioninfo()
# Out:
# Julia Version 1.8.2
# Commit 36034abf260 (2022-09-29 15:21 UTC)
# Platform Info:
#   OS: macOS (arm64-apple-darwin21.3.0)
#   CPU: 8 × Apple M1
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-13.0.1 (ORCJIT, apple-m1)
#   Threads: 1 on 4 virtual cores
# Environment:
#   JULIA_NUM_THREADS =
